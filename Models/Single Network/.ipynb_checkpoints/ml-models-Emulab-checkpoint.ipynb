# %% [markdown]
# ### Load Label Indexes
# This chunk loads a file that contains the labels we want to load from the datasets as well as their indicies.

# %%
import numpy as np
import pandas as pd
import re
from sklearn.decomposition import PCA, FactorAnalysis
from sklearn.preprocessing import StandardScaler
from sklearn import tree
from sklearn import svm
import matplotlib.pyplot as plt
import matplotlib
import os
import seaborn as sn
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydot
from graphviz import Source
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import tree
from sklearn.datasets import load_wine
from IPython.display import SVG
from graphviz import Source
from IPython.display import display
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from imblearn.over_sampling import (RandomOverSampler, SMOTE, ADASYN)
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.utils import to_categorical
from keras.layers import Dropout
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix 
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import classification_report



# %matplotlib inline
class_names = ["Normal", "Corrupt", "Delay", "Duplicate", "Loss"]

seed = 0

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues, fig_size=(12,10)):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.

    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'
    """
    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    #classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        #print("Normalized confusion matrix")
    #else:
    #    print('Confusion matrix, without normalization')

    #print(cm)
    fig, ax = plt.subplots(figsize=fig_size, dpi= 80, facecolor='w', edgecolor='k')
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax
# Out:
# Using TensorFlow backend.

# %%
infile = open("../../tstat_labels_indexes.txt" ,'r')
data_field_list = []
for line in infile.readlines():
    if ":" in line:
        data_field = str(re.search('%s(.*)%s' % ("\"", "\""), line).group(1))
        index = int(re.search('%s(.*)%s' % (":", ","), line).group(1))
        data_field_list.append((data_field, index))

index_to_key_dict = {}
key_to_index_dict = {}
data_field_labels = []
for data_field, index in data_field_list:
    key_to_index_dict[data_field] = index
    index_to_key_dict[index] = data_field
    data_field_labels.append(data_field)

# %% [markdown]
# ### Read in a dataset file

# %%
def read_in_file(file_name):
    infile = open(file_name, 'r')
    header = infile.readline().split(' ')
    entries = []
    labels = None
    for i, line in enumerate(infile.readlines()):
        row = get_data_row(line)
        row = clean_data_row(row)
        if row != []:
            entries.append(row)
    entries = np.array(entries)
    return entries

# %% [markdown]
# ### Get data row
# Called by the read in file function. Loads a single line from the dataset files. Super inefficient, but only loads labels which are in the data field list.

# %%
def get_data_row(line):
    global index_to_key_dict
    line = line.split(' ')
    row = []
    labels = []
    c_pkt_cnt = 0
    s_pkt_cnt = 0
    c_bytes_cnt = 0
    s_bytes_cnt = 0
    for data_field, index in data_field_list:
        #print("df:", data_field,"ix:",index)
        #print(line)
        
        
        if data_field == "client_pkt_cnt":
            try:
                c_pkt_cnt = line[index]
                c_pkt_cnt = max(float(c_pkt_cnt), 1)
            except:
                c_pkt_cnt = 1
            #if c_pkt_cnt < 32:
            #    return []
        elif data_field == "serv_pkt_cnt":
            try:
                s_pkt_cnt = line[index]
                s_pkt_cnt = max(float(s_pkt_cnt), 1)
            except:
                s_pkt_cnt = 1
        elif data_field == "client_bytes_cnt":
            try:
                c_bytes_cnt = line[index]
                c_bytes_cnt = max(float(c_bytes_cnt), 1)
            except:
                c_bytes_cnt = 1
        elif data_field == "serv_bytes_cnt":
            try:
                s_bytes_cnt = line[index]
                s_bytes_cnt = max(float(s_bytes_cnt), 1)
            except:
                s_bytes_cnt = 1
                
    for data_field, index in data_field_list:
        try:
            val = line[index]
            val = float(val)
        except:
            val = 0
        row.append(val)    
    return row

# %%
#def metricName(index):

# %% [markdown]
# ### Clean data row
# Not implemented

# %%
def clean_data_row(in_row):
    global index_to_key_dict, key_to_index_dict
    return in_row

# %% [markdown]
# ### Get dataset
# Loads all files from a directory

# %%
def get_dataset(path):
    print(path)
    out_data = []
    file = open('summary.out', 'w')
    for sub_dir in os.listdir(path):
        temp_path = os.path.join(path, sub_dir)
        temp_path = os.path.join(temp_path, "log_tcp_complete")
        print (temp_path)
        if os.path.isfile(temp_path): 
            temp_data = read_in_file(temp_path)
            #print(temp_data[:,9])
            #print (len(temp_data), len(out_data))
            if len(temp_data) == 0:
                continue
            if out_data == []:
                out_data = temp_data
            else:
                out_data = np.concatenate((out_data, temp_data))
    file.close
    return out_data

# %% [markdown]
# ### Load DTN datasets
# Load all datasets
# Create numerical lables for each class, and a different set of labels for each subclass.

# %%
normal = np.nan_to_num(get_dataset("../../DataSet/emulab/normal"))
corr_01 = np.nan_to_num(get_dataset("../../DataSet/emulab/corrupt_0.1perc"))
corr_05 =  np.nan_to_num(get_dataset("../../DataSet/emulab/corrupt_5perc"))
corr_10 = np.nan_to_num(get_dataset("../../DataSet/emulab/corrupt_1.0perc"))
delay_1_1 = np.nan_to_num(get_dataset("../../DataSet/emulab/delay_1_var_1"))
delay_5_2 = np.nan_to_num(get_dataset("../../DataSet/emulab/delay_5_var_2"))
delay_10_5 = np.nan_to_num(get_dataset("../../DataSet/emulab/delay_10_var_5"))
delay_25_20 = np.nan_to_num(get_dataset("../../DataSet/emulab/delay_25_var_20"))
drop_1 = np.nan_to_num(get_dataset("../../DataSet/emulab/loss_1_perc"))
drop_2 = np.nan_to_num(get_dataset("../../DataSet/emulab/loss_1perc"))
drop_3 = np.nan_to_num(get_dataset("../../DataSet/emulab/loss_5_perc"))
drop_4 = np.nan_to_num(get_dataset("../../DataSet/emulab/loss_5perc"))
drop_5 = np.nan_to_num(get_dataset("../../DataSet/emulab/loss_10perc"))
drop_6 = np.nan_to_num(get_dataset("../../DataSet/emulab/loss_10_perc"))
drop_7 = np.nan_to_num(get_dataset("../../DataSet/emulab/loss_15perc"))
dup_1 = np.nan_to_num(get_dataset("../../DataSet/emulab/dup_1perc"))
dup_5 = np.nan_to_num(get_dataset("../../DataSet/emulab/dup_5perc"))
dup_7 = np.nan_to_num(get_dataset("../../DataSet/emulab/dup_7perc"))

print(normal.shape)
normal = normal[normal[:,2] > 200]
print(normal.shape)

print(corr_01.shape)
corr_01 = corr_01[corr_01[:,2] > 200]
print(corr_01.shape)

print(corr_05.shape)
corr_05 = corr_05[corr_05[:,2] > 200]
print(corr_05.shape)

print(corr_10.shape)
corr_10 = corr_10[corr_10[:,2] > 200]
print(corr_10.shape)

print(delay_1_1.shape)
delay_1_1 = delay_1_1[delay_1_1[:,2] > 200]
print(delay_1_1.shape)

print(delay_5_2.shape)
delay_5_2 = delay_5_2[delay_5_2[:,2] > 200]
print(delay_5_2.shape)

print(delay_10_5.shape)
delay_10_5 = delay_10_5[delay_10_5[:,2] > 200]
print(delay_10_5.shape)

print(delay_25_20.shape)
delay_25_20 = delay_25_20[delay_25_20[:,2] > 200]
print(delay_25_20.shape)


print(drop_1.shape)
drop_1 = drop_1[drop_1[:,2] > 200]
print(drop_1.shape)

print(drop_2.shape)
drop_2 = drop_2[drop_2[:,2] > 200]
print(drop_2.shape)

print(drop_3.shape)
drop_3 = drop_3[drop_3[:,2] > 200]
print(drop_3.shape)

print(drop_4.shape)
drop_4 = drop_4[drop_4[:,2] > 200]
print(drop_4.shape)

print(drop_5.shape)
drop_5 = drop_5[drop_5[:,2] > 200]
print(drop_5.shape)

print(drop_6.shape)
drop_6 = drop_6[drop_6[:,2] > 200]
print(drop_6.shape)

print(drop_7.shape)
drop_7 = drop_7[drop_7[:,2] > 200]
print(drop_7.shape)

print(dup_1.shape)
dup_1 = dup_1[dup_1[:,2] > 200]
print(dup_1.shape)

print(dup_5.shape)
dup_5 = dup_5[dup_5[:,2] > 200]
print(dup_5.shape)

print(dup_7.shape)
dup_7 = dup_7[dup_7[:,2] > 200]
print(dup_7.shape)



#print(dtn_normal)



l1  = np.ones(len(normal  ))    *1
l2  = np.ones(len(corr_01  ))   *2
l3  = np.ones(len(corr_05  ))   *2
l4  = np.ones(len(corr_10  ))   *2
l5  = np.ones(len(delay_1_1))   *3
l6  = np.ones(len(delay_5_2))   *3
l7  = np.ones(len(delay_10_5))  *3
l8  = np.ones(len(delay_25_20)) *3
l9  = np.ones(len(drop_1 ) )     *4
l10  = np.ones(len(drop_2 ) )     *4
l11  = np.ones(len(drop_3 ) )     *4
l12  = np.ones(len(drop_4 ) )     *4
l13  = np.ones(len(drop_5 ) )     *4
l14  = np.ones(len(drop_6 ) )     *4
l15  = np.ones(len(drop_7 ) )     *4
l16  = np.ones(len(dup_1))      *5
l17  = np.ones(len(dup_5))       *5
l18  = np.ones(len(dup_7))       *5



emulab_data = np.concatenate((normal, corr_01, corr_05, corr_10, delay_1_1, delay_5_2, delay_10_5, delay_25_20,
                           drop_1, drop_2, drop_3, drop_4, drop_5, drop_6, drop_7, dup_1, dup_5, dup_7))

pandas_dtn = pd.DataFrame(data=emulab_data, 
              columns=data_field_labels)
all_data = MinMaxScaler().fit_transform(pandas_dtn)


labels = np.concatenate((l1, l2, l3, l4, l5, l6, l7, l8, l9, l10, l11, l12, l13, l14, l15, l16, l17, l18))
labels = pd.DataFrame(data=labels)
labels = labels.values.ravel()


print(all_data.shape)
print(labels.shape)
# Out:
# ./emulab/normal
# ./emulab/normal/2020_01_26_23_01.out/log_tcp_complete
# ./emulab/normal/2020_01_26_22_37.out/log_tcp_complete
# ./emulab/normal/2020_01_26_20_32.out/log_tcp_complete
# ./emulab/normal/2020_01_26_20_22.out/log_tcp_complete
# ./emulab/normal/2020_01_26_20_21.out/log_tcp_complete
# ./emulab/normal/2020_01_26_21_48.out/log_tcp_complete
# ./emulab/normal/2020_01_26_22_12.out/log_tcp_complete
# ./emulab/normal/2020_01_26_20_58.out/log_tcp_complete
# ./emulab/normal/2020_01_26_23_25.out/log_tcp_complete
# ./emulab/normal/2020_01_26_21_23.out/log_tcp_complete
# ./emulab/corrupt_0.1perc
# ./emulab/corrupt_0.1perc/2019_12_08_03_04.out/log_tcp_complete
# ./emulab/corrupt_0.1perc/2019_12_08_03_12.out/log_tcp_complete
# ./emulab/corrupt_0.1perc/2019_12_08_03_31.out/log_tcp_complete
# ./emulab/corrupt_0.1perc/2019_12_08_02_29.out/log_tcp_complete
# /Users/pooya/conda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   from ipykernel import kernelapp as app
# ./emulab/corrupt_0.1perc/2019_12_08_03_44.out/log_tcp_complete
# ./emulab/corrupt_5perc
# ./emulab/corrupt_5perc/2019_12_08_04_08.out/log_tcp_complete
# ./emulab/corrupt_5perc/2019_12_08_02_53.out/log_tcp_complete
# ./emulab/corrupt_5perc/2019_12_08_03_37.out/log_tcp_complete
# ./emulab/corrupt_5perc/2019_12_08_03_19.out/log_tcp_complete
# ./emulab/corrupt_5perc/2019_12_08_03_55.out/log_tcp_complete
# ./emulab/corrupt_1.0perc
# ./emulab/corrupt_1.0perc/2019_12_08_03_48.out/log_tcp_complete
# ./emulab/corrupt_1.0perc/2019_12_08_03_17.out/log_tcp_complete
# ./emulab/corrupt_1.0perc/2019_12_08_04_32.out/log_tcp_complete
# ./emulab/corrupt_1.0perc/2019_12_08_04_13.out/log_tcp_complete
# ./emulab/corrupt_1.0perc/2019_12_08_03_33.out/log_tcp_complete
# ./emulab/delay_1_var_1
# ./emulab/delay_1_var_1/2019_12_08_00_58.out/log_tcp_complete
# ./emulab/delay_1_var_1/2019_12_08_01_35.out/log_tcp_complete
# ./emulab/delay_1_var_1/2019_12_08_02_01.out/log_tcp_complete
# ./emulab/delay_1_var_1/2019_12_08_02_15.out/log_tcp_complete
# ./emulab/delay_1_var_1/2019_12_08_01_43.out/log_tcp_complete
# ./emulab/delay_5_var_2
# ./emulab/delay_5_var_2/2019_12_08_00_36.out/log_tcp_complete
# ./emulab/delay_5_var_2/2019_12_08_01_17.out/log_tcp_complete
# ./emulab/delay_5_var_2/2019_12_08_01_25.out/log_tcp_complete
# ./emulab/delay_5_var_2/2019_12_08_01_44.out/log_tcp_complete
# ./emulab/delay_5_var_2/2019_12_08_01_57.out/log_tcp_complete
# ./emulab/delay_10_var_5
# ./emulab/delay_10_var_5/2019_12_08_00_18.out/log_tcp_complete
# ./emulab/delay_10_var_5/2019_12_08_01_10.out/log_tcp_complete
# ./emulab/delay_10_var_5/2019_12_08_01_29.out/log_tcp_complete
# ./emulab/delay_10_var_5/2019_12_08_01_01.out/log_tcp_complete
# ./emulab/delay_10_var_5/2019_12_08_01_41.out/log_tcp_complete
# ./emulab/delay_25_var_20
# ./emulab/delay_25_var_20/2019_12_08_00_47.out/log_tcp_complete
# ./emulab/delay_25_var_20/2019_12_08_01_14.out/log_tcp_complete
# ./emulab/delay_25_var_20/2019_12_08_00_54.out/log_tcp_complete
# ./emulab/delay_25_var_20/2019_12_08_01_26.out/log_tcp_complete
# ./emulab/delay_25_var_20/2019_12_08_00_03.out/log_tcp_complete
# ./emulab/loss_1_perc
# ./emulab/loss_1_perc/2019_12_08_00_22.out/log_tcp_complete
# ./emulab/loss_1_perc/2019_12_07_22_55.out/log_tcp_complete
# ./emulab/loss_1_perc/2019_12_08_00_04.out/log_tcp_complete
# ./emulab/loss_1_perc/2019_12_08_00_16.out/log_tcp_complete
# ./emulab/loss_1_perc/2019_12_07_23_49.out/log_tcp_complete
# ./emulab/loss_1perc
# ./emulab/loss_1perc/.DS_Store/log_tcp_complete
# ./emulab/loss_1perc/2019_11_08_01_17.out/log_tcp_complete
# ./emulab/loss_5_perc
# ./emulab/loss_5_perc/2019_12_08_00_21.out/log_tcp_complete
# ./emulab/loss_5_perc/2019_12_08_00_45.out/log_tcp_complete
# ./emulab/loss_5_perc/2019_12_07_23_19.out/log_tcp_complete
# ./emulab/loss_5_perc/2019_12_08_00_40.out/log_tcp_complete
# ./emulab/loss_5_perc/2019_12_08_00_13.out/log_tcp_complete
# ./emulab/loss_5perc
# ./emulab/loss_5perc/2019_11_08_02_13.out/log_tcp_complete
# ./emulab/loss_5perc/2019_11_08_01_37.out/log_tcp_complete
# ./emulab/loss_10perc
# ./emulab/loss_10perc/2019_11_08_01_53.out/log_tcp_complete
# ./emulab/loss_10_perc
# ./emulab/loss_10_perc/2019_12_08_00_36.out/log_tcp_complete
# ./emulab/loss_10_perc/2019_12_08_00_35.out/log_tcp_complete
# ./emulab/loss_10_perc/2019_12_07_23_41.out/log_tcp_complete
# ./emulab/loss_10_perc/2019_12_08_01_04.out/log_tcp_complete
# ./emulab/loss_10_perc/2019_12_08_00_57.out/log_tcp_complete
# ./emulab/loss_15perc
# ./emulab/loss_15perc/2019_11_08_02_06.out/log_tcp_complete
# ./emulab/dup_1perc
# ./emulab/dup_1perc/2019_12_08_01_59.out/log_tcp_complete
# ./emulab/dup_1perc/2019_12_08_02_18.out/log_tcp_complete
# ./emulab/dup_1perc/2019_12_08_02_31.out/log_tcp_complete
# ./emulab/dup_1perc/2019_12_08_01_15.out/log_tcp_complete
# ./emulab/dup_1perc/2019_12_08_01_51.out/log_tcp_complete
# ./emulab/dup_5perc
# ./emulab/dup_5perc/2019_12_08_02_24.out/log_tcp_complete
# ./emulab/dup_5perc/2019_12_08_02_43.out/log_tcp_complete
# ./emulab/dup_5perc/2019_12_08_02_55.out/log_tcp_complete
# ./emulab/dup_5perc/2019_12_08_01_39.out/log_tcp_complete
# ./emulab/dup_5perc/2019_12_08_02_16.out/log_tcp_complete
# ./emulab/dup_7perc
# ./emulab/dup_7perc/2019_12_08_02_40.out/log_tcp_complete
# ./emulab/dup_7perc/2019_12_08_03_07.out/log_tcp_complete
# ./emulab/dup_7perc/2019_12_08_02_48.out/log_tcp_complete
# ./emulab/dup_7perc/2019_12_08_03_19.out/log_tcp_complete
# ./emulab/dup_7perc/2019_12_08_02_04.out/log_tcp_complete
# (1904, 89)
# (952, 89)
# (1140, 89)
# (546, 89)
# (982, 89)
# (427, 89)
# (1110, 89)
# (530, 89)
# (954, 89)
# (365, 89)
# (1050, 89)
# (463, 89)
# (968, 89)
# (376, 89)
# (955, 89)
# (360, 89)
# (1135, 89)
# (542, 89)
# (238, 89)
# (119, 89)
# (1040, 89)
# (462, 89)
# (299, 89)
# (119, 89)
# (191, 89)
# (74, 89)
# (986, 89)
# (422, 89)
# (183, 89)
# (68, 89)
# (1190, 89)
# (595, 89)
# (1191, 89)
# (596, 89)
# (1190, 89)
# (595, 89)
# (7611, 89)
# (7611,)

# %% [markdown]
# ### Split Datasets (randomized on seed value)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(all_data, labels, random_state=seed)
train_data, train_labels = SMOTE().fit_resample(train_data, train_labels)

# %% [markdown]
# # Single Networks :

# %% [markdown]
# ## DT:

# %%
dtn =  DecisionTreeClassifier()
dtn.fit(train_data, train_labels)
predicted_labels = dtn.predict(test_data)
report = classification_report(test_labels, predicted_labels, output_dict=True)
df = pd.DataFrame(report).transpose()
df.to_csv("emulab_model_emulab_data_DT_CR.csv", sep='\t')
plot_confusion_matrix(test_labels, predicted_labels, normalize=True,classes=class_names, title='')
plt.rcParams.update({'font.size': 30})
plt.savefig('dtn_model_dtn_data_DT.pdf')
plt.show()

# %% [markdown]
# ## RF :

# %%
dtn =  RandomForestClassifier(n_estimators = 1000, random_state = 42,n_jobs = -1)
dtn.fit(train_data, train_labels)
predicted_labels = dtn.predict(test_data)
report = classification_report(test_labels, predicted_labels, output_dict=True)
df = pd.DataFrame(report).transpose()
df.to_csv("emulab_model_emulab_data_RF_CR.csv", sep='\t')
plot_confusion_matrix(test_labels, predicted_labels, normalize=True,classes=class_names, title='')
plt.rcParams.update({'font.size': 30})
plt.savefig('emulab_model_emulab_data_RF.pdf')
plt.show()

# %% [markdown]
# ## SVM :

# %%
dtn = svm.SVC(kernel='linear', gamma ='auto', max_iter=10000)
dtn.fit(train_data, train_labels)
predicted_labels = dtn.predict(test_data)
report = classification_report(test_labels, predicted_labels, output_dict=True)
df = pd.DataFrame(report).transpose()
df.to_csv("emulab_model_emulab_data_SVM_CR.csv", sep='\t')
plot_confusion_matrix(test_labels, predicted_labels, normalize=True,classes=class_names, title='')
plt.rcParams.update({'font.size': 30})
plt.savefig('emulab_model_emulab_data_SVM.pdf')
plt.show()

# %% [markdown]
# ## NN :

# %%
#create model
model = Sequential()

#get number of columns in training data
n_cols = train_data.shape[1]

#add model layers
model.add(Dense(700, activation='relu', input_dim=n_cols))
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(6, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
early_stopping_monitor = EarlyStopping(patience=3)

train_labels_categorical = to_categorical(train_labels)

model.fit(train_data, train_labels_categorical, validation_split=0.2, epochs=10, callbacks=[early_stopping_monitor])
predicted_labels = model.predict(test_data)
plot_confusion_matrix(test_labels, np.argmax(predicted_labels, axis=1) , normalize=True,classes=class_names, title='')
plt.rcParams.update({'font.size': 30})
plt.savefig('dtn_model_dtn_data_NN.pdf')
plt.show()
# Out:
# Train on 5468 samples, validate on 1367 samples
# Epoch 1/10
# 5468/5468 [==============================] - 1s 148us/step - loss: 0.7658 - accuracy: 0.7178 - val_loss: 0.2298 - val_accuracy: 0.8925
# Epoch 2/10
# 5468/5468 [==============================] - 0s 84us/step - loss: 0.2392 - accuracy: 0.9142 - val_loss: 0.1215 - val_accuracy: 0.9642
# Epoch 3/10
# 5468/5468 [==============================] - 0s 76us/step - loss: 0.1643 - accuracy: 0.9428 - val_loss: 0.0602 - val_accuracy: 0.9795
# Epoch 4/10
# 5468/5468 [==============================] - 0s 80us/step - loss: 0.1286 - accuracy: 0.9552 - val_loss: 0.0429 - val_accuracy: 0.9854
# Epoch 5/10
# 5468/5468 [==============================] - 1s 93us/step - loss: 0.0986 - accuracy: 0.9680 - val_loss: 0.0547 - val_accuracy: 0.9781
# Epoch 6/10
# 5468/5468 [==============================] - 0s 83us/step - loss: 0.0886 - accuracy: 0.9706 - val_loss: 0.0607 - val_accuracy: 0.9781
# Epoch 7/10
# 5468/5468 [==============================] - 1s 98us/step - loss: 0.0827 - accuracy: 0.9729 - val_loss: 0.0412 - val_accuracy: 0.9810
# Epoch 8/10
# 5468/5468 [==============================] - 0s 91us/step - loss: 0.0739 - accuracy: 0.9766 - val_loss: 0.0369 - val_accuracy: 0.9832
# Epoch 9/10
# 5468/5468 [==============================] - 0s 86us/step - loss: 0.0742 - accuracy: 0.9768 - val_loss: 0.0509 - val_accuracy: 0.9824
# Epoch 10/10
# 5468/5468 [==============================] - 0s 91us/step - loss: 0.0636 - accuracy: 0.9782 - val_loss: 0.0493 - val_accuracy: 0.9817

# %% [markdown]
# # Combined Model :

# %% [markdown]
# ## DT:

# %%
all_ = DecisionTreeClassifier()
all_.fit(all_train_data, all_train_labels)
all_predicted_labels = all_.predict(all_test_data)

plot_confusion_matrix(all_test_labels, all_predicted_labels, normalize=True,classes=class_names, title='')
plt.rcParams.update({'font.size': 30})
plt.savefig('all_model_all_data_DT.pdf')
plt.show()

report = classification_report(all_test_labels,all_predicted_labels, output_dict=True)
df = pd.DataFrame(report).transpose()
df.to_csv("combine_model_DT_CR.csv", sep='\t')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ec2f240803dc> in <module>
#       1 all_ = DecisionTreeClassifier()
# ----> 2 all_.fit(all_train_data, all_train_labels)
#       3 all_predicted_labels = all_.predict(all_test_data)
#       4
#       5 plot_confusion_matrix(all_test_labels, all_predicted_labels, normalize=True,classes=class_names, title='')
#
# NameError: name 'all_train_data' is not defined

# %% [markdown]
# ## RF :

# %%
all_ =  RandomForestClassifier(n_estimators = 1000, random_state = 42,n_jobs = -1)
all_.fit(all_train_data, all_train_labels)
all_predicted_labels = all_.predict(all_test_data)

plot_confusion_matrix(all_test_labels, all_predicted_labels, normalize=True,classes=class_names, title='')

plt.rcParams.update({'font.size': 30})
plt.savefig('all_model_all_data_RF.pdf')
plt.show()
report = classification_report(all_test_labels,all_predicted_labels, output_dict=True)
df = pd.DataFrame(report).transpose()
df.to_csv("combine_model_RF_CR.csv", sep='\t')

# %% [markdown]
# ## SVM :

# %%
all_ = svm.SVC(kernel='linear', gamma ='auto', max_iter=10000)
all_.fit(all_train_data, all_train_labels)
all_predicted_labels = all_.predict(all_test_data)


plot_confusion_matrix(all_test_labels, all_predicted_labels, normalize=True,classes=class_names, title='')

plt.rcParams.update({'font.size': 30})
plt.savefig('all_model_all_data_SVM.pdf')
plt.show()
report = classification_report(all_test_labels,all_predicted_labels, output_dict=True)
df = pd.DataFrame(report).transpose()
df.to_csv("combine_model_SVM_CR.csv", sep='\t')

# %% [markdown]
# ## NN :
